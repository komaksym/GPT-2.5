# %%
corpus = """
low low low low low 
lower lower widest widest widest
newest newest newest newest newest newest 
"""

# %%
vocab_size = 263
num_of_merges = vocab_size - 256
vocab = []

# Pre-tokenization
def pretokenize(corpus):
    counts = {}
    for word in corpus.split():
        counts[word] = counts.get(word, 0) + 1
    return counts

corpus = pretokenize(corpus)

# %%
corpus.keys()
# Out:
# dict_keys(['low', 'lower', 'widest', 'newest'])

# %%
def split_into_bytes(corpus):
    # Split keys into characters
    corpus_n = {}
    for k, v in corpus.items():
        new_key = []
        for c in range(len(k) - 1):
            if k[c] + k[c + 1] not in vocab:
                new_key.append(k[c])
            else:
                new_key.append(k[c] + k[c + 1])
                continue

        new_key = tuple(new_key)
        corpus_n[new_key] = v
    return corpus_n

corpus = split_into_bytes(corpus)

# %%
corpus
# Out:
# {(): 6}

# %%
def count_bytepairs(corpus):
    counts = {}
    # Count byte pairs
    for k, v in corpus.items():
        for c1, c2 in zip(k, k[1:]):
            counts[(c1, c2)] = counts.get((c1, c2), 0) + v

    # Sort by the highest frequency
    counts = dict(sorted(counts.items(), key=lambda x: x[1], reverse=True))
    return counts

counts = count_bytepairs(corpus)
counts
# Out:
# {}

# %%
def get_merge(counts):
    # Get the max frequency
    maxf = counts[max(counts, key=counts.get)]

    # Get the candidates with the max frequency
    candidates = [k for k, v in counts.items() if v == maxf]
    # Pick the lexicographically greater pair
    merge = max(candidates)
    return merge

# %%
# Start merges
for _ in range(num_of_merges):
    # Get the most frequent pair
    merge = get_merge(counts)
    # Add the merge to the vocab
    vocab.append("".join(merge))
    # Apply the merge to the corpus
    pass
    # Count byte pairs again
    pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 4
#       1 # Start merges
#       2 for _ in range(num_of_merges):
#       3     # Get the most frequent pair
# ----> 4     merge = get_merge(counts)
#       5     # Add the merge to the vocab
#       6     vocab.append("".join(merge))
#
# Cell In[110], line 3, in get_merge(counts)
#       1 def get_merge(counts):
#       2     # Get the max frequency
# ----> 3     maxf = counts[max(counts, key=counts.get)]
#       5     # Get the candidates with the max frequency
#       6     candidates = [k for k, v in counts.items() if v == maxf]
#
# ValueError: max() iterable argument is empty
